# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshiniSada/CSS-website/blob/main/LabTask2_ColabPrograms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ✅ VERSION 1: HARDCODING VARIABLES

# %%
# Title: Version 1 – Hardcoded Variables

x = 10
y = 20

result = x + y

print(f"Hardcoded Addition: {x} + {y} = {result}")
# Out:
# Hardcoded Addition: 10 + 20 = 30

# %% [markdown]
# ✅ VERSION 2: KEYBOARD INPUT

# %%
# Title: Version 2 – Keyboard Input
# Keyboard input

try:
    x = int(input("Enter the first number: "))
    y = int(input("Enter the second number: "))

    result = x + y
    print(f"User Input Addition: {x} + {y} = {result}")

except ValueError:
    print("Please enter valid integers!")
# Out:
# Enter the first number: 5
# Enter the second number: 7
# User Input Addition: 5 + 7 = 12

# %% [markdown]
# ✅ VERSION 3: READ FROM FILE (SINGLE INPUT)

# %%
# Title: Version 3 – Read From File (Single Input)
# Save the file in the runtime (for demonstration)

with open("single_input.txt", "w") as f:
    f.write("42")

# Reading single input from a file
try:
    with open("single_input.txt", "r") as f:
        num = int(f.read().strip())

    result = num * 2
    print(f"Single Input Read from File: {num} * 2 = {result}")

except FileNotFoundError:
    print("File not found!")

except ValueError:
    print("Error in reading or converting the input!")
# Out:
# Single Input Read from File: 42 * 2 = 84

# %% [markdown]
# ✅ VERSION 4: READ FROM FILE (MULTIPLE INPUTS)

# %%
# Title: Version 4 – Read From File (Multiple Inputs)
# Save a file with multiple inputs

with open("multiple_inputs.txt", "w") as f:
    f.write("3\n5\n7")

# Reading multiple inputs from a file
try:
    with open("multiple_inputs.txt", "r") as f:
        numbers = [int(line.strip()) for line in f.readlines()]

    result = sum(numbers)
    print(f"Multiple Inputs Read from File: {numbers}, Sum = {result}")

except FileNotFoundError:
    print("File not found!")

except ValueError:
    print("Error in reading or converting the inputs!")
# Out:
# Multiple Inputs Read from File: [3, 5, 7], Sum = 15

# %% [markdown]
# ✅ VERSION 5: DEBUGGING AND FIXING ERRORS

# %%
# Title: Version 5 – Debugging and Error Handling

try:
    a = int(input("Enter a number: "))
    b = int(input("Enter another number: "))

    result = a / b
    print(f"Division Result: {result}")

except ValueError:
    print("Please enter valid integers!")

except ZeroDivisionError:
    print("Division by zero is not allowed!")
# Out:
# Enter a number: 10
# Enter another number: 0
# Division by zero is not allowed!

# %%
# !git remote remove origin

# %%
# !git remote add origin https://github.com/HarshiniSada/ColabPrograms.git

# %%
# !ls
# Out:
# multiple_inputs.txt  sample_data  single_input.txt
